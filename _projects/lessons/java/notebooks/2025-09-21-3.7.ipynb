# %% [raw]
# ---
# title: Class Variables and Methods
# layout: post
# points: 1
# categories: [Java, Class-Variables-and-Methods]
# lesson_language: Java
# lesson_topic: Class-Variables-and-Methods
# description: Use class variables/methods for shared states.
# lesson_source: APCSA
# lesson_type: lesson
# codemirror: true
# title: Class Variables and Methods
# description: Compare instance and static variables, write class methods, and lock values in place with final.
# menu: nav/csa_units/csaunit3.html
# permalink: /csa/unit_03/3_7
# courses:
#     csa:
#         week: 5
# menu: nav/csa_units/csaunit3.html
# author: Lucas
# ---

# %% [markdown]
# ## 1. Reference Guide
#
# | Concept                           | Key idea                                                            | Java example                                | Important note                                          |
# | --------------------------------- | ------------------------------------------------------------------- | ------------------------------------------- | ------------------------------------------------------- |
# | **Instance variable**             | Belongs to an individual object                                     | `private String name;`                      | Every object gets its own copy                          |
# | **Class variable**                | Belongs to the class and is shared by all objects                   | `private static int numberOfStudents;`      | Declared with `static`                                  |
# | **`static`**                      | Makes a variable/method belong to the class rather than an instance | `public static int count;`                  | Access class members through the class when appropriate |
# | **Public class variable**         | A class variable accessible outside its class                       | `public static int players;`                | Access with `Game.players`                              |
# | **Class method**                  | A method belonging to the class                                     | `public static int doubleValue(int x)`      | Can be called without creating an object                |
# | **Static method access**          | Static methods can access static/class members                      | `count++`                                   | They **cannot directly access instance variables**      |
# | **Dot operator**                  | Used to access public class members                                 | `MathHelper.doubleValue(5)`                 | Typically `ClassName.member`                            |
# | **`final` variable**              | A variable whose value cannot be reassigned after initialization    | `public static final int DAYS_IN_WEEK = 7;` | Often used for constants                                |
# | **Shared state**                  | All instances see the same class-variable value                     | `Student.numberOfStudents`                  | Changing it affects what all objects see                |
# | **Constructor + static variable** | A constructor can update shared class state                         | `numberOfStudents++;`                       | Useful for tracking how many objects have been created  |

# %% [markdown]
# ## 2. LxD Design Process
#
# 1. **Baseline**. Students already understand instance vars/obj, so treat that as a bridge.
# 2. Contrast instance vars with `static` class vars before introducting static methods.
# 3. Use concrete code examples to demonstrate shared state (`Student.numberOfStudents`)
# 4. **Misconceptions**. show that a static method cannot directly access an instance variable
# 5. Introduce `final` after `static` so students can distinguish *shared* from *immutable*
# 6. **Apply**. Follow TODOs to develop the `BankAccount` class with automated tasks.

# %% [markdown]
# ## 3. Collegeboard Requirements
#
# - **3.7.A** Develop code to define behaviors of a class through class methods.
#     - *3.7.A.1* Class methods cannot access or change the values of instance variables or call instance methods without being passed an instance of the class via a parameter.
#     - *3.7.A.2* Class methods can access or change the values of class variables and can call other class methods
# - **3.7.B** Develop c

# %% [markdown]
# ## 4. Lesson Objectives/Plan
# - Define **class variables** and **class methods** using `static`
# - Explain how class variables are shared by all objects of a class, and what class methods can/cannot access
# - Use a **class name and dot operator** to access public class variables/methods
# - Explain what the `final` keyword does

# %% [markdown]
# ## 5. Code Examples
#
# ### Instance vs. Class Variables
#
# Recall that an *instance variable belongs to an individual object*, so let's say we have:
# ```java
# public class Student {
#     private String name;
#     private int grade;
# }
# ```
# and we define 3 students
# ```java
# Student s1 = new Student();
# Student s2 = new Student();
# Student s3 = new Student();
# ```
#
# Each student gets their own `name` and `grade`.
#
# Class variables are different in that they *belong to the class itself*:
# ```java
# public class Student {
#     private String name;
#     private int grade;
#
#     public static int numberOfStudents = 0;
# }
# ```
#
# Now, each student `s1`, `s2`, `s3`, shares one copy of `numberOfStudents`.
#
# For example, we could make a class:
# ```java
# public class Student {
#     private String name;
#
#     public static int numberOfStudents = 0;
#
#     public Student(String n) {
#         name = n;
#         numberOfStudents++;
#     }
# }
# ```
# and create a few objects:
# ```java
# Student a = new Student("Alice");
# Student b = new Student("Bob");
# Student c = new Student("Charlie");
# ```
# which makes `Student.numberOfStudents` `3`.

# %% [markdown]
# ### Static
#
# We use `static` to denote that a variable or method belongs to the class itself rather than to an individual object.
#
# This would be an instance variable:
# ```java
# private String name;
# ```
# and this would be a class variable:
# ```java
# private static int numberOfStudents;
# ```

# %% [markdown]
# ### Public and Private
#
# If we want some class variable to be accessible outside of the class, we can declare it as `public`:
# ```java
# public class Game {
#     public static int players = 0;
# }
# ```
# which means we can do:
# ```java
# System.out.println(Game.players); // get # of players
# Game.players = 5; // modify # of players
# ```

# %% [markdown]
# ### Class Methods
#
# Similarly, we can define a method as `static` to denote it belongs to a class:
# ```java
# public class MathHelper {
#
#     public static int doubleValue(int x) {
#         return x * 2;
#     }
# }
# ```
#
# Now we can call it without creating a `MathHelper` object:
# ```java
# int result = MathHelper.doubleValue(5);
#
# System.out.println(result); // 10
# ```
#
# Class methods can access class variables, other class methods, its parameters, and local variables, but NOT instance variables:
# ```java
# public class Counter {
#
#     private static int count = 0;
#
#     public static void increase() {
#         count++;
#     }
#
#     public static int getCount() {
#         return count;
#     }
#
#     public static void reset() {
#         count = 0;
#     }
#
#     public static void resetAndIncrease() {
#         reset();
#         increase();
#     }
# }
# ```
#
# We CANNOT do this
# ```java
# public class Student {
#     private String name;
#
#     public static void printName() {
#         System.out.println(name); // ERROR
#     }
# }
# ```

# %% [markdown]
# ### `final` Variables
#
# We define a variable as `final` if we want it to be immutable.
# ```java
# public static final int DAYS_IN_WEEK = 7;
# ```

# %% [markdown]
# ## 6. Hacks
#
# ### Popcorn Hack #1
#
# Modify the code so that creating each `Student` automatically increments the shared `numberOfStudents` counter.
#
# {% capture p1 %}
# public class Student {
#     private String name;
#     public static int numberOfStudents = 0;
#
#     public Student(String name) {
#         this.name = name;
#         // TODO: Increment the shared student counter
#     }
#
#     public static void main(String[] args) {
#         Student a = new Student("Alice");
#         Student b = new Student("Bob");
#         Student c = new Student("Charlie");
#
#         System.out.println(Student.numberOfStudents); // 3
#     }
# }
# {% endcapture %}
# {% include runners/code.html runner_id="java-main" language="java" code=p1 %}

# %% [markdown]
# ### Popcorn Hack #2
# Fix the code so that `printName()` can still be a `static` method. You might have to change what the method accepts.
#
# {% capture p2 %}
# public class Student {
#     private String name;
#
#     public Student(String name) {
#         this.name = name;
#     }
#
#     public static void printName() {
#         System.out.println(name);
#     }
#
#     public static void main(String[] args) {
#         Student s = new Student("Alice");
#         Student.printName();
#     }
# }
# {% endcapture %}
# {% include runners/code.html runner_id="java-main" language="java" code=p2 %}

# %% [markdown]
# ### Homework
#
# In this assignment, you'll be modifying a partially implemented Java class called `BankAccount`.
#
# Unzip the file under `_projects/lessons/java/static/3-7_bank.zip`, which contains a simple Java Maven project. Complete the TODOs listed, and run tests using `mvn test`. Submit your source `BankAccount.java` file (see below).

# %% [markdown]
# ### Rubric
#
# | Component               | Criteria                                                                                     | Number | Points Each |    Total |
# | ----------------------- | -------------------------------------------------------------------------------------------- | -----: | ----------: | -------: |
# | **Popcorn Hack 1**      | Student correctly implements the shared `static` counter                                     |      1 |        0.15 | **0.15** |
# | **Popcorn Hack 2**      | Student correctly modifies the static method to work with instance data                      |      1 |        0.15 | **0.15** |
# | **Homework Unit Tests** | Each passing unit test demonstrates correct implementation of the `BankAccount` requirements |     10 |        0.06 | **0.60** |
# | **Total**               |                                                                                              | **12** |             | **0.90** |
#
#
# ### Submission
#
# 1. Create a new notebook in your portfolio homework area: _notebooks/homework.
# 2. Add one raw cell at the top with the frontmatter:
# ```yaml
# ---
# layout: post
# codemirror: true
# title: Class Variables and Methods HW
# categories: [Java]
# lesson_language: Java
# lesson_topic: Class-Variables-and-Methods HW
# lesson_part: interactive
# lesson_type: lesson
# permalink: /csa/unit_03/3_7-hw
# author: <yourGithubID>
# ---
# ```
#
# Add a code cell with the `BankAccount` code snippet (or just run it directly by importing it as a `.java` file), then submit the notebook/Java file with these details:
# ```
# Lesson: CSA 3.7 Class Methods and Variables
# Popcorn Hack 1: completed? (y/n)
# Popcorn Hack 2: completed? (y/n)
# Homework: tests passed (x/10)
# ```
